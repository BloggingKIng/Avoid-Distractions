# %% [markdown]
# ### Testing Notebook

# %%
import psutil
import time
import pygetwindow 
import pyautogui

# %%
browsers  = {
    'chrome.exe':'Google Chrome',
    'firefox.exe':'Firefox',
    'msedge.exe':'Edge',
}

blocked_sites = [
    'Facebook', 'YouTube', 'Twitter', 'Instagram', 'Reddit', 'TikTok', 'Snapchat', 'Discord', 'X'
]

# %%
windows = pygetwindow.getWindowsWithTitle('edge')

# %%
windows
# Out:
# [Win32Window(hWnd=2164874)]

# %%
windows[0].isMaximized
# Out:
# True

# %%
windows[0].maximize()

# %%
try:
    windows[0].activate()
except:
    pass

# %%
windows[0].isActive
# Out:
# False

# %%
while True:
    try:
        time.sleep(2)
        processes_running = psutil.process_iter()
        for processes in processes_running:
            process_name = processes.name().lower()
            if process_name in browsers.keys():
                print(browsers[process_name])
                windows = pygetwindow.getWindowsWithTitle(browsers[process_name])
                print(windows)
                for window in windows:
                    window_title = window.title.lower()
                    print(window_title)
                    for site in blocked_sites:
                        if site.lower() in window_title:
                            print(f'Blocking {site}')
                            print('Don\'t get distracted!')
                            try:
                                window.maximize()
                                time.sleep(1)
                                window.activate()
                                time.sleep(1)
                                pyautogui.click(window.center)
                            except:
                                pass
                            if window.isMaximized:
                                time.sleep(1)
                                pyautogui.hotkey('ctrl', 'w')
                                time.sleep(2)
                            break
    except KeyboardInterrupt:
        break
    except Exception as e:
        pass
# Out:
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# [Win32Window(hWnd=853998)]
# new tab - personal - microsoft​ edge
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# [Win32Window(hWnd=853998)]
# facebook – log in or sign up - personal - microsoft​ edge
# Blocking Facebook
# Don't get distracted!
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Edge
# []
# Edge
# []
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Edge
# []
# Edge
# []
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# python - change the active window - stack overflow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Edge
# []
# Edge
# []
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# window.activate() not working in jupyter notebook · issue #16 · asweigart/pygetwindow - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# youtube - google chrome
# Blocking YouTube
# Don't get distracted!
# Google Chrome
# [Win32Window(hWnd=5048202)]
# (44) 25 things players hate in clash of clans! (part 11) - youtube - google chrome
# Blocking YouTube
# Don't get distracted!
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Edge
# []
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Edge
# []
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# youtube - google chrome
# Blocking YouTube
# Don't get distracted!
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Edge
# []
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Edge
# []
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Edge
# []
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Edge
# []
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
# Google Chrome
# [Win32Window(hWnd=5048202)]
# browser activity tracker - google chrome
